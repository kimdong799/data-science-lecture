# %% [markdown]
# # 빅데이터분석 WEEK_1

# %% [markdown]
# -----------------------

# %% [markdown]
# ### 출석 10, 과제 20, 기말 40, 기타 30

# %% [markdown]
# ### 데이터수집, 전처리, 분석, 시각화 다루는 교과목

# %% [markdown]
# ### 데이터 분석의 전 과정을 실습하는 과정

# %% [markdown]
# ### 텍스트 DATA에 초점을 맞춰 교과목 진행

# %% [markdown]
# ------------------------

# %% [markdown]
# # Python Review

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 넘파이처럼 C로 구현되어있어 같은 2차원 배열을 다루더라도 넘파이의 행렬 매트릭스를 다루는 능력이 탁월!

# %% [markdown]
# ### 쉽게 판다스는 스프레드 시트를 다룬다고 생각하면 쉬움

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
sr = pd.Series([17000,18000,1000,5000], index=['피자','치킨','콜라','사이다'])

print(sr)
# Out:
# 피자     17000
# 치킨     18000
# 콜라      1000
# 사이다     5000
# dtype: int64

# %%
values = [[1,2,3],[4,5,6],[7,8,9]]
ind1 = ['one','two','three']
col1 = ['A','B','C']
df = pd.DataFrame(values, index=ind1, columns=col1)
print(df)
# Out:
#        A  B  C
# one    1  2  3
# two    4  5  6
# three  7  8  9

# %%
data = {'학번':['1000','1001','1002','1003','1004','1005'],
       '이름':['Steve','James','Doyeon','Jane','Pilwoond','Tony'],
       '점수':[90.72, 78.09, 98.43, 64.19, 81.3, 99.14]}

df = pd.DataFrame(data)
print(df)
# Out:
#      학번        이름     점수
# 0  1000     Steve  90.72
# 1  1001     James  78.09
# 2  1002    Doyeon  98.43
# 3  1003      Jane  64.19
# 4  1004  Pilwoond  81.30
# 5  1005      Tony  99.14

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.mean()
# Out:
# 학번    1.666834e+22
# 점수    8.531167e+01
# dtype: float64

# %%
sr1 = df.mean()

# %%
df = df.append(sr1,ignore_index=True)

# %%
df.fillna(value='-')
# Out:
#             학번        이름         점수
# 0         1000     Steve  90.720000
# 1         1001     James  78.090000
# 2         1002    Doyeon  98.430000
# 3         1003      Jane  64.190000
# 4         1004  Pilwoond  81.300000
# 5         1005      Tony  99.140000
# 6  1.66683e+22         -  85.311667

# %%
df.dropna() # 행 삭제
# Out:
#      학번        이름     점수
# 0  1000     Steve  90.72
# 1  1001     James  78.09
# 2  1002    Doyeon  98.43
# 3  1003      Jane  64.19
# 4  1004  Pilwoond  81.30
# 5  1005      Tony  99.14

# %%
df.tail(2)
# Out:
#             학번    이름         점수
# 5         1005  Tony  99.140000
# 6  1.66683e+22   NaN  85.311667

# %%
df['이름']
# Out:
# 0       Steve
# 1       James
# 2      Doyeon
# 3        Jane
# 4    Pilwoond
# 5        Tony
# 6         NaN
# Name: 이름, dtype: object

# %%
df[0:2]
# Out:
#      학번     이름     점수
# 0  1000  Steve  90.72
# 1  1001  James  78.09

# %%
df[3:5]
# Out:
#      학번        이름     점수
# 3  1003      Jane  64.19
# 4  1004  Pilwoond  81.30

# %%
df.T # 행열 변환
# Out:
#         0      1       2      3         4      5            6
# 학번   1000   1001    1002   1003      1004   1005  1.66683e+22
# 이름  Steve  James  Doyeon   Jane  Pilwoond   Tony          NaN
# 점수  90.72  78.09   98.43  64.19      81.3  99.14      85.3117

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df = pd.read_excel("../data/casualty.xlsx")

# %%
df.head(5)
# Out:
#        Acc_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0  197901A11AD14                  2                   1               1
# 1  197901A1BAW34                  1                   1               3
# 2  197901A1BFD77                  1                   1               1
# 3  197901A1BFD77                  1                   2               2
# 4  197901A1BFD77                  2                   3               1
#
#    Gender_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# 0                   1                    -1                  3
# 1                   2                     6                  3
# 2                   1                     5                  3
# 3                   1                     4                  3
# 4                   1                     6                  3
#
#    Pedestrian_Location  Pedestrian_Movement  Car_Passenger  \
# 0                    0                    0              0
# ...

# %%
df.tail(5)
# Out:
#            Acc_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 93040  197906P001185                  1                   1               3
# 93041  197906P001187                  1                   1               3
# 93042  197906P001188                  1                   1               1
# 93043  197906P001199                  1                   1               1
# 93044  197906P001202                  2                   1               1
#
#        Gender_of_Casualty  Age_Band_of_Casualty  Casualty_Severity  \
# 93040                   1                     1                  3
# 93041                   2                     7                  3
# 93042                   1                     6                  3
# 93043                   1                     7                  3
# 93044                   2                     3                  3
#
#        Pedestrian_Location  Pedestrian_Movement  Car_Passenger  \
# ...

# %%
print("경영정보학과 60161051 김동현")
# Out:
# 경영정보학과 60161051 김동현

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93045 entries, 0 to 93044
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Acc_Index                           93045 non-null  object
#  1   Vehicle_Reference                   93045 non-null  int64
#  2   Casualty_Reference                  93045 non-null  int64
#  3   Casualty_Class                      93045 non-null  int64
#  4   Gender_of_Casualty                  93045 non-null  int64
#  5   Age_Band_of_Casualty                93045 non-null  int64
#  6   Casualty_Severity                   93045 non-null  int64
#  7   Pedestrian_Location                 93045 non-null  int64
#  8   Pedestrian_Movement                 93045 non-null  int64
#  9   Car_Passenger                       93045 non-null  int64
#  10  Bus_or_Coach_Passenger              93045 non-null  int64
# ...

# %%
# 1. 기록된 전체 교통사고 건수는 93045건

# %%
# 2. 남성, 여성의 교통사고 건수는?

# %%
df['Gender_of_Casualty'].unique() # 1: 남성, 2: 여성
# Out:
# array([ 1,  2, -1], dtype=int64)

# %%
sex = df['Gender_of_Casualty'].value_counts()

# %%
print(sex)
# Out:
#  1    59778
#  2    32961
# -1      306
# Name: Gender_of_Casualty, dtype: int64

# %%
# 남성 교통사고 건수: 59778건, 여성 교통사고 건수: 32961건

# %%
# 3. 사고가 일어나는 버스 안에서 가장 위험한 사람은?

# %%
df['Bus_or_Coach_Passenger'].unique()
# Out:
# array([ 0,  1, -1,  4,  2,  3], dtype=int64)

# %%
bus = df['Bus_or_Coach_Passenger'].value_counts()

# %%
print(bus)
# Out:
#  0    88722
# -1     1837
#  1     1371
#  4      551
#  3      354
#  2      210
# Name: Bus_or_Coach_Passenger, dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(data = df, x= df['Bus_or_Coach_Passenger'])

# %%
# 사고가 일어나는 버스 안에서 가장 위험한 사람은 0값에 해당하는
# 버스에 탄 승객이 아니며 압도적으로 많은 수치를 보임. 88722건

# %%
# 4. 전체 casualty type 중 가장 많은 사고 종류와 가장 적은 사고 종류는?

# %%
df['Casualty_Type'].unique()
# Out:
# array([104,   0, 109,  11,  19,   1,  90, 113,   2, 108, 103, 105, 110],
#       dtype=int64)

# %%
casualty_type = df['Casualty_Type'].value_counts()

# %%
print(casualty_type)
# Out:
# 109    37273
# 0      23006
# 104    14305
# 1       6555
# 11      4488
# 19      2866
# 2       2291
# 108      754
# 113      710
# 90       377
# 103      247
# 110      143
# 105       30
# Name: Casualty_Type, dtype: int64

# %%
casualty_type.sort_values(ascending=False)
# Out:
# 109    37273
# 0      23006
# 104    14305
# 1       6555
# 11      4488
# 19      2866
# 2       2291
# 108      754
# 113      710
# 90       377
# 103      247
# 110      143
# 105       30
# Name: Casualty_Type, dtype: int64

# %%
sns.countplot(data = df, x= df['Casualty_Type'])

# %%
#Casualty Type중 가장 많은 사고 종류는 109에 해당하는 차량탑승자(개인용 렌트카 포함)이다.
# 37273건
#가장 적은 사고 종류는 105에 해당하는 (오토바이-콤비네이션 라이더 또는 조수석)이다.
# 30건

# %% [markdown]
# ## 개인톡 과제

# %% [markdown]
# # 60161051 경영정보학과 김동현

# %%
driver = df[df['Casualty_Class']==1]

# %%
driver
# Out:
#            Acc_Index  Vehicle_Reference  Casualty_Reference  Casualty_Class  \
# 0      197901A11AD14                  2                   1               1
# 2      197901A1BFD77                  1                   1               1
# 4      197901A1BFD77                  2                   3               1
# 10     197901A1DAK71                  2                   2               1
# 13     197901A1FBK75                  1                   1               1
# ...              ...                ...                 ...             ...
# 93037  197906P001182                  1                   1               1
# 93039  197906P001183                  1                   2               1
# 93042  197906P001188                  1                   1               1
# 93043  197906P001199                  1                   1               1
# 93044  197906P001202                  2                   1               1
#
# ...

# %%
driver_df = driver[['Casualty_Type']]
driver_df
# Out:
#        Casualty_Type
# 0                104
# 2                109
# 4                109
# 10               109
# 13               109
# ...              ...
# 93037            104
# 93039            104
# 93042            109
# 93043            109
# 93044              1
#
# [46327 rows x 1 columns]

# %%
driver_ct = driver_df['Casualty_Type'].value_counts()

# %%
driver_ct
# Out:
# 109    21469
# 104    12802
# 1       6502
# 2       2243
# 19      1858
# 113      569
# 103      222
# 90       220
# 108      210
# 11       164
# 110       44
# 105       24
# Name: Casualty_Type, dtype: int64

# %%
# 운전자들이 가장 많이 당하는 사고종류는 109에 해당하는 차량탑승자(개인용 렌트카 포함)21469건이며,
# 두번째로 가장 많이 당하는 사고는 104에 해당하는 오토바이 라이더 또는 승객 12802건이다.
