# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 지금까지 표 형테의 데이터를 딥러닝 모델을 활용해 학습해보았습니다.

# %% [markdown]
# 요즘 딥러닝의 대표로 유명한 자율주행 데이터는 표형태가 아닌 데이터 학습은 어떻게 할까요??

# %% [markdown]
# 가장 간단한 형태의 이미지 분류를 해보겠습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 카메라 기술이 발전하고 누구나 카메라를 사용할 수 있게 되면서 우리는 상당히 많은 데이터를 이미지의 형태로 저장하고 사용합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 사진을 찍고 이미지를 검색하는 것을 매우 일상적인 일이 되었습니다.

# %% [markdown]
# 인류에게는 꿈이 있었습니다. 바로 컴퓨터에게 보는 법을 알려주는 것입니다.
#
# 사물을 보고 어떤 사물인지 이해하는 방법을 컴퓨터에게도 알려주고 싶었습니다.
#
# 처음에는 사람보다 계산을 훨씬 잘하는 컴퓨터들이 2 3살 아이도 잘 할 수 있는 개와 고양이의 구분이 어렵지 않다고 생각했죠

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# AI의 선구자 중 한 사람인 민스키 박사는 MIT 학부 신입생에게 방학과제로 컴퓨터 비전 과제를 내줍니다.
#
# 무려 1966년이었죠 다시 말하지만 대학생 1학년에게 방학과제로 준것입니다.
#
# 당연히 쉬운일이 아니었죠 컴퓨터 비전은 고사하고 이미지 분류조차 할 수 없었죠
#
# 2012년 힌팅교수가 이미지 분류 딥러닝 모델 AlexNet 발표하기 전까지 그 누구도 해결하지 못한 과제였습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 우리는 이번 수업에서 손글씨 이미지 분류기와 사진 이미지를 분류하는 문제를 다루어 볼것입니다.

# %% [markdown]
# 물론 이번에도 지난 수업과 마찬가지로 가장 간단한 형태의 코드를 반복 경험하면서 수업을 진행할 예정입니다.
