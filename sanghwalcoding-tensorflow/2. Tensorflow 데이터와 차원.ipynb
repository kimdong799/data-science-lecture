# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 컴퓨터에게 이미지를 학습시키기 위해서는 먼저 이미지 데이터가 어떻게 생겼는지에 대한 이해가 필요합니다.
#
# 데이터 과학 분야가 어려운 이유 중 하나가 바로 용어입니다.
#
# 그야말로 용어 지옥이라고 할 수 있죠

# %% [markdown]
# 특히 어려움을 가중시키는 요인은 다음처럼 3가지가 있습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 이번 수업에서 우리가 공부할 차원도 바로 이 3번째의 그것입니다.
#
# 이제부터 차원이라는 말에 두가지 의미를 알아봅시다.
#
# 어떤 때는 표의 열, 칼럼의 관점에서 차원을 이야기하고
#
# 어떤 때는 데이터 사이의 포함관계를 바라보는 관점에서 차원을 이야기 합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 칼럼의 관점에서 차원을 사용하는 경우입니다.

# %% [markdown]
# 온도, 판매량 변수 2개로 이루어진 데이터가 있습니다.
#
# 관측치는 5개이구요.
#
# 각 데이터들은 2차원의 좌표 평면 위에 나타낼 수 있는데 5개의 점으로 표현 가능합니다.
#
# 각 점은 1개의 관측치를 나타내죠

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 습도라는 변수를 추가하여 변수가 3개인 표를 구성한다면 데이터는 3차원 공간의 한 점으로 표현됩니다.
#
# 만약 칼럼의 숫자가 N개라면 각 데이터는 N차원 공간의 1점으로 표현할 수 있습니다.
#
# 즉 변수의 갯수는 데이터를 표현하는 공간에 차원 수 와 같습니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 표의 데이터를 공간으로 옮기게 되면 우리는 모든 데이터들을 기하학적인 관점으로 바라보고 해석할 수 있게 됩니다.
#
# 다시 말하면 데이터들간의 거리를 잴 수 있고 데이터 사이에 가까운 정도를 숫자로 정밀하게 비교 가능하다는 의미입니다.
#
# 이렇듯 차원을 말할 때 데이터를 공간속에 표현한다는 맥락에서 사용한다면 변수의 갯수가 공간의 차원수가 되는 것입니다.

# %% [markdown]
# 이번에는 데이터 포함 관계의 관점에서 차원이 사용되는 것을 살펴보겠습니다.

# %% [markdown]
# 데이터 포함 관계는 배열의 깊이와 관련이 있습니다.
#
# 아이리스 데이터를 보면 각 데이터는 4차원 공간에 표현된 데이터 입니다.
#
# 열이 4개니까 4차원입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 관측치 하나를 코드로 표현해봅시다.
#
# 이렇게 하나의 배열에 값이 들어가 있는 모양을 1차원이라고 합니다.
#
# x1의 shape를 출력하면 숫자가 1개 들어가있죠 그래서 1차원입니다.
#
# 4의 의미는 4개의 요소를 지닌다는 뜻이에요
#
# 다른 두개의 관측치도 각각 같은 코드로 작성해볼 수 있습니다.
#
# 표는 이 관측치들의 모음으로 만들게 되는데 이것을 코드로 표현하면 다음과 같습니다.
#
# 1차원 배열 세개를 품고있는 배열 하나가 만들어졌습니다.
#
# 즉 배열의 깊이가 2가 되었고 깊이가 2라서 shape을 출력하면 2개의 숫자가 들어있고 2차원 형태라고 합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 이렇듯 차원을 말할 때 데이터의 형태를 표현하는 맥락에서 사용하면 배열의 깊이는 차원수가 됩니다.
#
# 보시는 것처럼 차원이라는 말은 맥락적으로 다르게 사용됩니다.
#
# 변수의 숫자, 배열의 깊이를 차원 수로 이해할 때가 있습니다.

# %% [markdown]
# 이렇게 차원을 설명하는 이유는 표가 아닌 데이터, 우리가 지금 부터 다루려는 이미지는 표의 관측치처럼 1차원 형태가 아니기 때문입니다.
#
# 이제 우리는 표를 벗어난 데이터를 이해할 준비가 되었습니다.
#
# 이미지 파일 하나가 데이터 관점에서는 관측치 하나라고 할 수 있는데요
#
# 흑백의 이미지는 데이터 하나가 2차원 형태를 가집니다.
#
# 지금 sample로 구성한 데이터는 2,2 shape을 가지고 있는데요 가로 2픽셀, 세로 2픽셀로 되어있어요

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 출력해보면 이렇게 생긴 이미지 입니다.
#
# 이미지 데이터 자체는 나중에 다뤄볼 것입니다.
#
# 지금은 데이터 모양 차원에 집중해주세요

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 이미지를 2개 더 추가했습니다.
#
# 파이썬에서 이런 종류의 데이터를 선언할 때 줄바꿈이 의미가 없는데요 코드가 한줄로 되어 있어 img1 을 만들때 작성한 코드와 달라 보이지만 같은 형태의 데이터를 만드는 코드입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 이미지들을 모아 이미지 셋을 구성했습니다.
#
# 이렇게 만들어진 이미지 셋을 3차원 형태로 표현되고 3, 2, 2 모양인것을 알 수 있습니다.
#
# 여기서 관측치들은 모두 가지고 있는 요소들의 갯수가 4입니다.
#
# 데이터 형태를 표현하는 관점에서 img는 2차원의 형태로 서로 다르지만 데이터 공간의 맥락에서는 x1, img1 모두 동일하게 4차원 공간에 1점으로 표현할 수 있는 관측치입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 데이터 형태의 맥락에서 한번 더 연습해보겠습니다.
#
# 이렇게 표현하면 d1은 1차원 형태의 데이터입니다.
#
# d2는 d1을 5개 가지고 있어요 따라서 2차원 형태입니다.
#
# shape를 출력하면 5, 3 두가지 숫자를 가지고 있죠
#
# d3는 d2를 4개 가지고 있어요 shape는 4, 5, 3이고 3차원 형태입니다.
#
# d4는 d3를 두개 가지고 있네요
#
# shape의 숫자가 4개니까 4차원 형태입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 데이터 형태의  맥락에서 배열의 깊이가 차원수 라는 것이 조금 더 이해가 가시나요?

# %% [markdown]
# 이렇게 1차원, 2차원 등 여러 형태로 구성되어 있는 데이터의 모습을 Tensor라고 합니다.
#
# 우리가 지금 사용하는 라이브러리가 Tensorflow죠? tensorflow는 이러한 tensor가 흘러가면서 모델을 학습한다는 것에 착안하여 이러한 이름이 붙은것입니다.

# %% [markdown]
# ![image.png](attachment:image.png)
